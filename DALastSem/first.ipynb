# %%
#find y=mx+c
#y is dependent on x and x is independent,c is intercept,c is point where the point coincide on line 
#y=m1x1+.................mNxN
import pandas as pd
import seaborn as sea
import matplotlib.pylab as plat
import numpy as np
data=pd.read_csv("C:\\Users\\ahire\\OneDrive\\Desktop\\Advertising.csv")
print(data.head(10))
x=np.array(data[["TV Ad Budget ($)"]])#there are [[]] bcoz its 2D 
y=np.array(data[["Sales ($)"]])
plat.scatter(x,y,color="red")
# Out:
#    Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# 0           1             230.1                 37.8                     69.2
# 1           2              44.5                 39.3                     45.1
# 2           3              17.2                 45.9                     69.3
# 3           4             151.5                 41.3                     58.5
# 4           5             180.8                 10.8                     58.4
# 5           6               8.7                 48.9                     75.0
# 6           7              57.5                 32.8                     23.5
# 7           8             120.2                 19.6                     11.6
# 8           9               8.6                  2.1                      1.0
# 9          10             199.8                  2.6                     21.2
#
#    Sales ($)
# 0       22.1
# 1       10.4
# 2        9.3
# 3       18.5
# 4       12.9
# 5        7.2
# ...

# %%
from PIL import Image
import numpy as np #numerical
import pandas as pd #patterns
import seaborn as sns
import statsmodels #use function(ols summary:sumrray like r2)
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #training keliye adha and testing keliye half data from total data
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error #model evaluation
#------------------------------data gathering-----------------------------
data=pd.read_csv("C:\\Users\\ahire\\OneDrive\\Desktop\\Advertising.csv")
data.head()
#-------------------------------EDA----------------------------------------
print(data.columns)
print(data.shape)
# Out:
# Index(['Unnamed: 0', 'TV Ad Budget ($)', 'Radio Ad Budget ($)',
#        'Newspaper Ad Budget ($)', 'Sales ($)'],
#       dtype='object')
# (200, 5)
