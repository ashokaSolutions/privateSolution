# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plat
import numpy as np
import statsmodels #use function(ols summary:sumrray like r2)
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression,LogisticRegression

from sklearn.model_selection import train_test_split #training keliye adha and testing keliye half data from total data
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,accuracy_score,confusion_matrix,classification_report #model evaluation
data1=pd.read_csv("C:\\Users\\ahire\\OneDrive\\Desktop\\user.csv")#1 confusion_matrix tp,tn,fp,fn,classification_report recall wagera
print(data1["Gender"].unique)
data1["Gender"]=data["Gender"].replace({"Male":1,"Female":0},inplace=True)
print(data1.head())
data1.info()
# Out:
# <bound method Series.unique of 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 395    Female
# 396      Male
# 397    Female
# 398      Male
# 399    Female
# Name: Gender, Length: 400, dtype: object>
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   None   19            19000          0
# 1  15810944   None   35            20000          0
# 2  15668575   None   26            43000          0
# 3  15603246   None   27            57000          0
# 4  15804002   None   19            76000          0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           0 non-null      object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           0 non-null      object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data1["Purchased"].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
sns.distplot(data1["Age"])
# Out:
# C:\Users\ahire\AppData\Local\Temp\ipykernel_12424\3479527783.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1["Age"])
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
x=data1[["Purchased"]]
y=data1["Purchased"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)#6 imp
lo=LogisticRegression()
lo.fit(x_train,y_train)#7
y_pred=lo.predict(x_test)
y_prob=lo.predict_proba(x_test)#8
test_accuracy=accuracy_score(y_test,x_test)
con_matrix=confusion_matrix(y_test,y_pred)
matrix=pd.crosstab(y_test,y_pred,rownames=["Actual"],colnames=["Predicted"])
sns.heatmap(matrix,annot=True)
# Out:
# <AxesSubplot: xlabel='Predicted', ylabel='Actual'>

# %%
class_report=classification_report(y_test,y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
